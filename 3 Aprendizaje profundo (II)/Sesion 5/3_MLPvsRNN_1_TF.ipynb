# %% [markdown]
# <a href="https://colab.research.google.com/github/vicentcamison/idal_ia3/blob/main/3%20Aprendizaje%20profundo%20(II)/Sesion%205/3_MLPvsRNN_1_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![IDAL](https://i.imgur.com/tIKXIG1.jpg)
#
# #**Máster en Inteligencia Artificial Avanzada y Aplicada:  IA^3**
# ---

# %% [markdown]
# #<strong><center>Series temporales con RNNs y MLP en KERAS</center></strong>

# %% [markdown]
# En este documento vamos a estudiar las posibilidades de las RNNs como modelos predictivos de series temporales.
# Las series temporales son un campo directo de aplicación de las redes recurrentes, si bien es cierto que los mejores resultados se obtienen cuando empleamos modelos más potentes como las GRUs o LSTM.
#
# En el ejercicio vamos a crear una red recurrente básica en TensorFlow, usando KERAS y a ver qué resultados obtiene en predicción con una serie generada artificialmente.  Además, vamos a comparar sus resultados con los de una red neuronal feedforward (no recurrente) que prepararemos (y entrenaremos) para la misma prediccion temporal.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# Vamos a generar la serie temporal y observar qué aspecto tiene. La serie la componemos a partir de una tendencia (*trend*) un patron estacional (*seasonal pattern*), una oscilación periodica (*seasonality*) y ruido (*noise*).

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
series = trend(time, 0.1)  
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Creamos la serie
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Le sumamos ruido
series += noise(time, noise_level, seed=42)

# Establecemos conjunto de entrenamiento y validación
split_time = 1000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

# Parámetros para preparar las entradas al modelo
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
plt.figure(figsize=(10, 6))

plot_series(time_train, x_train)
plot_series(time_valid, x_valid)

# %%
print(time_train.size)
print(time_valid.size)
# Out:
# 1000
# 461

# %% [markdown]
# En el ejemplo creado hemos especificado un periodo de 4 años (tomando como que son valores diarios) de los cuales los primeros 1000 serán el conjunto de entrenamiento y los siguientes 461 serán los valores para validar e intentar predecir

# %% [markdown]
# Definimos una función auxiliar para preparar los datos de entrada en bloques de tantas entradas como hayamos especificado en la ventana temporal y en los lotes correspondientes.

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %% [markdown]
# # Modelo con RNN

# %% [markdown]
# Preparamos la sesion de Keras y el conjunto de entrenamiento, en entradas eventanadas y en los lotes especificados

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

train_set = windowed_dataset(x_train, window_size, batch_size=128, shuffle_buffer=shuffle_buffer_size)

# %% [markdown]
# Definimos el modelo en Keras

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, None, 1)           0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, None, 40)          1680
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 40)                3240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 1)                 0
# =================================================================
# Total params: 4,961
# Trainable params: 4,961
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Definimos una función callback para que vaya ajustando la tasa de aprendizaje y  el optimizador a emplear

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)

# %% [markdown]
# Compilamos el modelo, dejandolo listo para entrenar

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %% [markdown]
# Entrenamos, guardando los resultados en `history`

# %%
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 30ms/step - loss: 194.6263 - mae: 195.1263
# Epoch 2/100
# 8/8 [==============================] - 0s 29ms/step - loss: 195.2580 - mae: 195.7580
# Epoch 3/100
# 8/8 [==============================] - 0s 31ms/step - loss: 193.9793 - mae: 194.4793
# Epoch 4/100
# 8/8 [==============================] - 0s 26ms/step - loss: 192.3059 - mae: 192.8059
# Epoch 5/100
# 8/8 [==============================] - 0s 28ms/step - loss: 189.4673 - mae: 189.9673
# Epoch 6/100
# 8/8 [==============================] - 0s 32ms/step - loss: 187.5114 - mae: 188.0114
# Epoch 7/100
# 8/8 [==============================] - 0s 29ms/step - loss: 185.2977 - mae: 185.7977
# Epoch 8/100
# 8/8 [==============================] - 0s 26ms/step - loss: 183.4114 - mae: 183.9114
# Epoch 9/100
# 8/8 [==============================] - 0s 26ms/step - loss: 180.7796 - mae: 181.2796
# Epoch 10/100
# 8/8 [==============================] - 0s 26ms/step - loss: 176.5626 - mae: 177.0626
# Epoch 11/100
# 8/8 [==============================] - 0s 25ms/step - loss: 172.3047 - mae: 172.8047
# Epoch 12/100
# 8/8 [==============================] - 0s 28ms/step - loss: 167.3889 - mae: 167.8889
# Epoch 13/100
# 8/8 [==============================] - 0s 27ms/step - loss: 162.5601 - mae: 163.0601
# Epoch 14/100
# 8/8 [==============================] - 0s 31ms/step - loss: 154.1899 - mae: 154.6899
# Epoch 15/100
# 8/8 [==============================] - 0s 25ms/step - loss: 146.8882 - mae: 147.3882
# Epoch 16/100
# 8/8 [==============================] - 0s 27ms/step - loss: 137.2157 - mae: 137.7157
# Epoch 17/100
# 8/8 [==============================] - 0s 27ms/step - loss: 124.9229 - mae: 125.4229
# Epoch 18/100
# 8/8 [==============================] - 0s 26ms/step - loss: 108.4339 - mae: 108.9339
# Epoch 19/100
# 8/8 [==============================] - 0s 28ms/step - loss: 88.2527 - mae: 88.7527
# Epoch 20/100
# 8/8 [==============================] - 0s 29ms/step - loss: 62.6947 - mae: 63.1947
# Epoch 21/100
# 8/8 [==============================] - 0s 28ms/step - loss: 34.4743 - mae: 34.9717
# Epoch 22/100
# 8/8 [==============================] - 0s 27ms/step - loss: 24.8572 - mae: 25.3542
# Epoch 23/100
# 8/8 [==============================] - 0s 27ms/step - loss: 23.2316 - mae: 23.7294
# Epoch 24/100
# 8/8 [==============================] - 0s 28ms/step - loss: 21.5919 - mae: 22.0883
# Epoch 25/100
# 8/8 [==============================] - 0s 25ms/step - loss: 17.7768 - mae: 18.2727
# Epoch 26/100
# 8/8 [==============================] - 0s 32ms/step - loss: 14.5748 - mae: 15.0648
# Epoch 27/100
# 8/8 [==============================] - 0s 27ms/step - loss: 10.9263 - mae: 11.4149
# Epoch 28/100
# 8/8 [==============================] - 0s 27ms/step - loss: 9.6484 - mae: 10.1360
# Epoch 29/100
# 8/8 [==============================] - 0s 29ms/step - loss: 8.3422 - mae: 8.8231
# Epoch 30/100
# 8/8 [==============================] - 0s 30ms/step - loss: 7.7374 - mae: 8.2191
# Epoch 31/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.8057 - mae: 8.2859
# Epoch 32/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.1916 - mae: 7.6698
# Epoch 33/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.2634 - mae: 7.7403
# Epoch 34/100
# 8/8 [==============================] - 0s 29ms/step - loss: 8.0607 - mae: 8.5389
# Epoch 35/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.3852 - mae: 7.8662
# Epoch 36/100
# 8/8 [==============================] - 0s 25ms/step - loss: 7.5370 - mae: 8.0163
# Epoch 37/100
# 8/8 [==============================] - 0s 26ms/step - loss: 7.4615 - mae: 7.9401
# Epoch 38/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.4145 - mae: 7.8897
# Epoch 39/100
# 8/8 [==============================] - 0s 26ms/step - loss: 7.2729 - mae: 7.7470
# Epoch 40/100
# 8/8 [==============================] - 0s 24ms/step - loss: 7.3074 - mae: 7.7837
# Epoch 41/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.3650 - mae: 7.8424
# Epoch 42/100
# 8/8 [==============================] - 0s 25ms/step - loss: 7.4751 - mae: 7.9595
# Epoch 43/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.3051 - mae: 7.7861
# Epoch 44/100
# 8/8 [==============================] - 0s 27ms/step - loss: 6.9602 - mae: 7.4341
# Epoch 45/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.1033 - mae: 7.5853
# Epoch 46/100
# 8/8 [==============================] - 0s 28ms/step - loss: 6.6968 - mae: 7.1774
# Epoch 47/100
# 8/8 [==============================] - 0s 30ms/step - loss: 6.8120 - mae: 7.2889
# Epoch 48/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.3882 - mae: 7.8713
# Epoch 49/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.1568 - mae: 7.6414
# Epoch 50/100
# 8/8 [==============================] - 0s 28ms/step - loss: 6.6858 - mae: 7.1640
# Epoch 51/100
# 8/8 [==============================] - 0s 28ms/step - loss: 7.1206 - mae: 7.6038
# Epoch 52/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.3728 - mae: 7.8565
# Epoch 53/100
# 8/8 [==============================] - 0s 29ms/step - loss: 6.8408 - mae: 7.3255
# Epoch 54/100
# 8/8 [==============================] - 0s 28ms/step - loss: 6.5050 - mae: 6.9832
# Epoch 55/100
# 8/8 [==============================] - 0s 25ms/step - loss: 7.1512 - mae: 7.6341
# Epoch 56/100
# 8/8 [==============================] - 0s 29ms/step - loss: 6.0473 - mae: 6.5241
# Epoch 57/100
# 8/8 [==============================] - 0s 29ms/step - loss: 6.1097 - mae: 6.5849
# Epoch 58/100
# 8/8 [==============================] - 0s 26ms/step - loss: 8.2514 - mae: 8.7399
# Epoch 59/100
# 8/8 [==============================] - 0s 27ms/step - loss: 7.4804 - mae: 7.9684
# Epoch 60/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.4598 - mae: 7.9465
# Epoch 61/100
# 8/8 [==============================] - 0s 26ms/step - loss: 7.1124 - mae: 7.5952
# Epoch 62/100
# 8/8 [==============================] - 0s 31ms/step - loss: 10.6078 - mae: 11.0967
# Epoch 63/100
# 8/8 [==============================] - 0s 26ms/step - loss: 10.4636 - mae: 10.9526
# Epoch 64/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.2013 - mae: 7.6863
# Epoch 65/100
# 8/8 [==============================] - 0s 26ms/step - loss: 9.0523 - mae: 9.5415
# Epoch 66/100
# 8/8 [==============================] - 0s 27ms/step - loss: 9.7020 - mae: 10.1888
# Epoch 67/100
# 8/8 [==============================] - 0s 30ms/step - loss: 8.0449 - mae: 8.5331
# Epoch 68/100
# 8/8 [==============================] - 0s 27ms/step - loss: 10.5248 - mae: 11.0164
# Epoch 69/100
# 8/8 [==============================] - 0s 25ms/step - loss: 14.5455 - mae: 15.0412
# Epoch 70/100
# 8/8 [==============================] - 0s 27ms/step - loss: 9.9748 - mae: 10.4673
# Epoch 71/100
# 8/8 [==============================] - 0s 28ms/step - loss: 9.4440 - mae: 9.9325
# Epoch 72/100
# 8/8 [==============================] - 0s 29ms/step - loss: 12.0877 - mae: 12.5793
# Epoch 73/100
# 8/8 [==============================] - 0s 29ms/step - loss: 9.1637 - mae: 9.6533
# Epoch 74/100
# 8/8 [==============================] - 0s 29ms/step - loss: 7.8894 - mae: 8.3757
# Epoch 75/100
# 8/8 [==============================] - 0s 26ms/step - loss: 6.4321 - mae: 6.9168
# Epoch 76/100
# 8/8 [==============================] - 0s 28ms/step - loss: 10.1676 - mae: 10.6590
# Epoch 77/100
# 8/8 [==============================] - 0s 28ms/step - loss: 9.1933 - mae: 9.6854
# Epoch 78/100
# 8/8 [==============================] - 0s 27ms/step - loss: 14.3632 - mae: 14.8592
# Epoch 79/100
# 8/8 [==============================] - 0s 28ms/step - loss: 24.5852 - mae: 25.0823
# Epoch 80/100
# 8/8 [==============================] - 0s 29ms/step - loss: 16.4021 - mae: 16.8939
# Epoch 81/100
# 8/8 [==============================] - 0s 30ms/step - loss: 20.0459 - mae: 20.5407
# Epoch 82/100
# 8/8 [==============================] - 0s 26ms/step - loss: 17.0192 - mae: 17.5129
# Epoch 83/100
# 8/8 [==============================] - 0s 26ms/step - loss: 14.7008 - mae: 15.1948
# Epoch 84/100
# 8/8 [==============================] - 0s 28ms/step - loss: 15.5779 - mae: 16.0703
# Epoch 85/100
# 8/8 [==============================] - 0s 29ms/step - loss: 14.1400 - mae: 14.6334
# Epoch 86/100
# 8/8 [==============================] - 0s 31ms/step - loss: 17.5813 - mae: 18.0763
# Epoch 87/100
# 8/8 [==============================] - 0s 26ms/step - loss: 27.6319 - mae: 28.1288
# Epoch 88/100
# 8/8 [==============================] - 0s 29ms/step - loss: 20.2227 - mae: 20.7189
# Epoch 89/100
# 8/8 [==============================] - 0s 28ms/step - loss: 21.3389 - mae: 21.8378
# Epoch 90/100
# 8/8 [==============================] - 0s 27ms/step - loss: 21.3669 - mae: 21.8636
# Epoch 91/100
# 8/8 [==============================] - 0s 29ms/step - loss: 19.4248 - mae: 19.9197
# Epoch 92/100
# 8/8 [==============================] - 0s 28ms/step - loss: 20.6646 - mae: 21.1627
# Epoch 93/100
# 8/8 [==============================] - 0s 29ms/step - loss: 26.0793 - mae: 26.5768
# Epoch 94/100
# 8/8 [==============================] - 0s 28ms/step - loss: 18.0579 - mae: 18.5545
# Epoch 95/100
# 8/8 [==============================] - 0s 28ms/step - loss: 38.6152 - mae: 39.1138
# Epoch 96/100
# 8/8 [==============================] - 0s 31ms/step - loss: 25.4238 - mae: 25.9199
# Epoch 97/100
# 8/8 [==============================] - 0s 27ms/step - loss: 31.2145 - mae: 31.7122
# Epoch 98/100
# 8/8 [==============================] - 0s 31ms/step - loss: 19.9068 - mae: 20.4018
# Epoch 99/100
# 8/8 [==============================] - 0s 29ms/step - loss: 37.7102 - mae: 38.2067
# Epoch 100/100
# 8/8 [==============================] - 0s 25ms/step - loss: 145.9562 - mae: 146.4559

# %% [markdown]
# Visualizamos el error para obtener los mejores parámetros, antes de realizar un entrenamiento más a fondo.

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 30])
# Out:
# (1e-08, 0.0001, 0.0, 30.0)

# %% [markdown]
# El error se muestra mínimo en torno a 5e-5 y con ese valor configuramos en entrenamiento final

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

dataset = windowed_dataset(x_train, window_size, batch_size=128, shuffle_buffer=shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])
# Ajustamos con el lr obtenido por el "callback" 
optimizer = tf.keras.optimizers.SGD(lr=5e-5, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(dataset,epochs=100)
# Out:
# Epoch 1/400
# 8/8 [==============================] - 1s 28ms/step - loss: 114.4029 - mae: 114.9029
# Epoch 2/400
# 8/8 [==============================] - 0s 27ms/step - loss: 22.2723 - mae: 22.7646
# Epoch 3/400
# 8/8 [==============================] - 0s 29ms/step - loss: 17.3886 - mae: 17.8839
# Epoch 4/400
# 8/8 [==============================] - 0s 29ms/step - loss: 13.2057 - mae: 13.7009
# Epoch 5/400
# 8/8 [==============================] - 0s 29ms/step - loss: 9.7382 - mae: 10.2275
# Epoch 6/400
# 8/8 [==============================] - 0s 27ms/step - loss: 15.2182 - mae: 15.7125
# Epoch 7/400
# 8/8 [==============================] - 0s 29ms/step - loss: 14.3017 - mae: 14.7927
# Epoch 8/400
# 8/8 [==============================] - 0s 29ms/step - loss: 10.7513 - mae: 11.2414
# Epoch 9/400
# 8/8 [==============================] - 0s 28ms/step - loss: 10.1877 - mae: 10.6791
# Epoch 10/400
# 8/8 [==============================] - 0s 28ms/step - loss: 9.2260 - mae: 9.7137
# Epoch 11/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.1169 - mae: 7.6029
# Epoch 12/400
# 8/8 [==============================] - 0s 25ms/step - loss: 6.8174 - mae: 7.2995
# Epoch 13/400
# 8/8 [==============================] - 0s 26ms/step - loss: 9.1717 - mae: 9.6576
# Epoch 14/400
# 8/8 [==============================] - 0s 26ms/step - loss: 9.6042 - mae: 10.0944
# Epoch 15/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.8559 - mae: 8.3471
# Epoch 16/400
# 8/8 [==============================] - 0s 26ms/step - loss: 6.7736 - mae: 7.2603
# Epoch 17/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.4621 - mae: 8.9514
# Epoch 18/400
# 8/8 [==============================] - 0s 26ms/step - loss: 11.4756 - mae: 11.9653
# Epoch 19/400
# 8/8 [==============================] - 0s 30ms/step - loss: 12.1857 - mae: 12.6795
# Epoch 20/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.4270 - mae: 8.9058
# Epoch 21/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.0082 - mae: 7.4965
# Epoch 22/400
# 8/8 [==============================] - 0s 26ms/step - loss: 7.8954 - mae: 8.3848
# Epoch 23/400
# 8/8 [==============================] - 0s 26ms/step - loss: 7.1549 - mae: 7.6425
# Epoch 24/400
# 8/8 [==============================] - 0s 26ms/step - loss: 6.7423 - mae: 7.2273
# Epoch 25/400
# 8/8 [==============================] - 0s 26ms/step - loss: 6.7265 - mae: 7.2110
# Epoch 26/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.3134 - mae: 5.7956
# Epoch 27/400
# 8/8 [==============================] - 0s 27ms/step - loss: 6.1635 - mae: 6.6435
# Epoch 28/400
# 8/8 [==============================] - 0s 31ms/step - loss: 11.5779 - mae: 12.0702
# Epoch 29/400
# 8/8 [==============================] - 0s 28ms/step - loss: 9.3459 - mae: 9.8339
# Epoch 30/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.6630 - mae: 7.1458
# Epoch 31/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.2277 - mae: 6.7071
# Epoch 32/400
# 8/8 [==============================] - 0s 28ms/step - loss: 8.2912 - mae: 8.7805
# Epoch 33/400
# 8/8 [==============================] - 0s 27ms/step - loss: 12.3575 - mae: 12.8502
# Epoch 34/400
# 8/8 [==============================] - 0s 30ms/step - loss: 10.9594 - mae: 11.4541
# Epoch 35/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.1327 - mae: 7.6192
# Epoch 36/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.0555 - mae: 6.5417
# Epoch 37/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.8102 - mae: 6.2900
# Epoch 38/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.0695 - mae: 5.5500
# Epoch 39/400
# 8/8 [==============================] - 0s 26ms/step - loss: 5.2548 - mae: 5.7332
# Epoch 40/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.5514 - mae: 7.0363
# Epoch 41/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.9936 - mae: 6.4755
# Epoch 42/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.0981 - mae: 5.5792
# Epoch 43/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.6746 - mae: 5.1525
# Epoch 44/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.9665 - mae: 5.4478
# Epoch 45/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.9283 - mae: 8.4172
# Epoch 46/400
# 8/8 [==============================] - 0s 27ms/step - loss: 6.8853 - mae: 7.3689
# Epoch 47/400
# 8/8 [==============================] - 0s 27ms/step - loss: 10.0866 - mae: 10.5771
# Epoch 48/400
# 8/8 [==============================] - 0s 30ms/step - loss: 7.0554 - mae: 7.5409
# Epoch 49/400
# 8/8 [==============================] - 0s 26ms/step - loss: 9.0023 - mae: 9.4926
# Epoch 50/400
# 8/8 [==============================] - 0s 27ms/step - loss: 7.1469 - mae: 7.6375
# Epoch 51/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.5194 - mae: 9.0108
# Epoch 52/400
# 8/8 [==============================] - 0s 25ms/step - loss: 7.3272 - mae: 7.8173
# Epoch 53/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.4821 - mae: 6.9637
# Epoch 54/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.6844 - mae: 5.1640
# Epoch 55/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.2162 - mae: 5.6993
# Epoch 56/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.5874 - mae: 7.0717
# Epoch 57/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.7312 - mae: 7.2135
# Epoch 58/400
# 8/8 [==============================] - 0s 28ms/step - loss: 10.0286 - mae: 10.5204
# Epoch 59/400
# 8/8 [==============================] - 0s 30ms/step - loss: 7.6266 - mae: 8.1160
# Epoch 60/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.5593 - mae: 6.0354
# Epoch 61/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6248 - mae: 5.1014
# Epoch 62/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.8306 - mae: 6.3162
# Epoch 63/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.7572 - mae: 6.2409
# Epoch 64/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.2836 - mae: 6.7687
# Epoch 65/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.7456 - mae: 8.2310
# Epoch 66/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.7702 - mae: 9.2576
# Epoch 67/400
# 8/8 [==============================] - 0s 27ms/step - loss: 8.8778 - mae: 9.3683
# Epoch 68/400
# 8/8 [==============================] - 0s 26ms/step - loss: 7.0074 - mae: 7.4936
# Epoch 69/400
# 8/8 [==============================] - 0s 28ms/step - loss: 9.4983 - mae: 9.9907
# Epoch 70/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.4092 - mae: 5.8879
# Epoch 71/400
# 8/8 [==============================] - 0s 26ms/step - loss: 5.1253 - mae: 5.6081
# Epoch 72/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.5280 - mae: 5.0005
# Epoch 73/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.4673 - mae: 4.9403
# Epoch 74/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.2694 - mae: 5.7521
# Epoch 75/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.3361 - mae: 5.8149
# Epoch 76/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.6461 - mae: 5.1256
# Epoch 77/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.2403 - mae: 5.7194
# Epoch 78/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.3678 - mae: 5.8512
# Epoch 79/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.4941 - mae: 4.9725
# Epoch 80/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.9874 - mae: 5.4668
# Epoch 81/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.5083 - mae: 4.9806
# Epoch 82/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1650 - mae: 5.6421
# Epoch 83/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.6203 - mae: 6.1026
# Epoch 84/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.9012 - mae: 5.3847
# Epoch 85/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.4451 - mae: 4.9270
# Epoch 86/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.2261 - mae: 5.7091
# Epoch 87/400
# 8/8 [==============================] - 0s 32ms/step - loss: 5.8675 - mae: 6.3487
# Epoch 88/400
# 8/8 [==============================] - 0s 25ms/step - loss: 5.4308 - mae: 5.9069
# Epoch 89/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.6293 - mae: 6.1129
# Epoch 90/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.7010 - mae: 5.1796
# Epoch 91/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.7608 - mae: 5.2394
# Epoch 92/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.0030 - mae: 5.4834
# Epoch 93/400
# 8/8 [==============================] - 0s 25ms/step - loss: 5.9301 - mae: 6.4140
# Epoch 94/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.8559 - mae: 6.3394
# Epoch 95/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.8955 - mae: 6.3799
# Epoch 96/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.8215 - mae: 6.3022
# Epoch 97/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.9253 - mae: 7.4058
# Epoch 98/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.5507 - mae: 8.0394
# Epoch 99/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9211 - mae: 5.3994
# Epoch 100/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.3669 - mae: 4.8432
# Epoch 101/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.5923 - mae: 5.0744
# Epoch 102/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.4203 - mae: 4.8999
# Epoch 103/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.4154 - mae: 4.8962
# Epoch 104/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4462 - mae: 4.9200
# Epoch 105/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.4005 - mae: 4.8751
# Epoch 106/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9025 - mae: 5.3821
# Epoch 107/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5200 - mae: 4.9948
# Epoch 108/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4451 - mae: 4.9238
# Epoch 109/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.5490 - mae: 5.0234
# Epoch 110/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.5728 - mae: 5.0509
# Epoch 111/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.8989 - mae: 5.3765
# Epoch 112/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.3269 - mae: 5.8024
# Epoch 113/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.1481 - mae: 5.6304
# Epoch 114/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.3838 - mae: 5.8625
# Epoch 115/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.8564 - mae: 5.3324
# Epoch 116/400
# 8/8 [==============================] - 0s 25ms/step - loss: 4.9684 - mae: 5.4488
# Epoch 117/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.0519 - mae: 5.5304
# Epoch 118/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.3851 - mae: 4.8580
# Epoch 119/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.0677 - mae: 5.5458
# Epoch 120/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6891 - mae: 5.1705
# Epoch 121/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.9183 - mae: 5.3970
# Epoch 122/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.0725 - mae: 6.5578
# Epoch 123/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.2245 - mae: 5.7027
# Epoch 124/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.0917 - mae: 6.5735
# Epoch 125/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.9903 - mae: 7.4789
# Epoch 126/400
# 8/8 [==============================] - 0s 27ms/step - loss: 7.0918 - mae: 7.5766
# Epoch 127/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.3938 - mae: 7.8852
# Epoch 128/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.3135 - mae: 5.7943
# Epoch 129/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.7780 - mae: 5.2535
# Epoch 130/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.3156 - mae: 6.8015
# Epoch 131/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.3604 - mae: 5.8379
# Epoch 132/400
# 8/8 [==============================] - 0s 30ms/step - loss: 8.5833 - mae: 9.0724
# Epoch 133/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.6777 - mae: 6.1541
# Epoch 134/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6972 - mae: 5.1773
# Epoch 135/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.7888 - mae: 7.2752
# Epoch 136/400
# 8/8 [==============================] - 0s 27ms/step - loss: 8.2585 - mae: 8.7494
# Epoch 137/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.8824 - mae: 5.3585
# Epoch 138/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.8703 - mae: 5.3502
# Epoch 139/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.6990 - mae: 5.1794
# Epoch 140/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.5799 - mae: 5.0568
# Epoch 141/400
# 8/8 [==============================] - 0s 26ms/step - loss: 5.0176 - mae: 5.4978
# Epoch 142/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.9843 - mae: 6.4669
# Epoch 143/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.0543 - mae: 7.5416
# Epoch 144/400
# 8/8 [==============================] - 0s 30ms/step - loss: 8.1557 - mae: 8.6457
# Epoch 145/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.5636 - mae: 6.0482
# Epoch 146/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.8979 - mae: 5.3797
# Epoch 147/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4898 - mae: 4.9676
# Epoch 148/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5960 - mae: 5.0729
# Epoch 149/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.4188 - mae: 4.8997
# Epoch 150/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4634 - mae: 4.9413
# Epoch 151/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.3503 - mae: 4.8298
# Epoch 152/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4522 - mae: 4.9260
# Epoch 153/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.1096 - mae: 6.5899
# Epoch 154/400
# 8/8 [==============================] - 0s 29ms/step - loss: 9.9211 - mae: 10.4136
# Epoch 155/400
# 8/8 [==============================] - 0s 30ms/step - loss: 7.6555 - mae: 8.1474
# Epoch 156/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.2415 - mae: 7.7284
# Epoch 157/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.4935 - mae: 5.9811
# Epoch 158/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.4951 - mae: 5.9778
# Epoch 159/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.8536 - mae: 5.3334
# Epoch 160/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.5904 - mae: 5.0679
# Epoch 161/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.0309 - mae: 5.5152
# Epoch 162/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5232 - mae: 5.0002
# Epoch 163/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5356 - mae: 5.0101
# Epoch 164/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6499 - mae: 5.1280
# Epoch 165/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.0076 - mae: 5.4829
# Epoch 166/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.2991 - mae: 4.7748
# Epoch 167/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.2870 - mae: 5.7680
# Epoch 168/400
# 8/8 [==============================] - 0s 30ms/step - loss: 7.1445 - mae: 7.6299
# Epoch 169/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1764 - mae: 5.6587
# Epoch 170/400
# 8/8 [==============================] - 0s 25ms/step - loss: 5.5890 - mae: 6.0711
# Epoch 171/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.1576 - mae: 4.6331
# Epoch 172/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.8880 - mae: 5.3684
# Epoch 173/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.3020 - mae: 5.7841
# Epoch 174/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.4513 - mae: 5.9349
# Epoch 175/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.6019 - mae: 5.0811
# Epoch 176/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.7638 - mae: 5.2445
# Epoch 177/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.3392 - mae: 4.8174
# Epoch 178/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.1553 - mae: 5.6390
# Epoch 179/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.1608 - mae: 5.6416
# Epoch 180/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.6531 - mae: 5.1339
# Epoch 181/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.7260 - mae: 5.2004
# Epoch 182/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.2135 - mae: 4.6913
# Epoch 183/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.8328 - mae: 5.3158
# Epoch 184/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.9800 - mae: 5.4545
# Epoch 185/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.2048 - mae: 6.6855
# Epoch 186/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.2598 - mae: 7.7499
# Epoch 187/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.7689 - mae: 6.2529
# Epoch 188/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.2839 - mae: 6.7693
# Epoch 189/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.2403 - mae: 5.7200
# Epoch 190/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.4355 - mae: 5.9132
# Epoch 191/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.5798 - mae: 5.0564
# Epoch 192/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.7933 - mae: 5.2709
# Epoch 193/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.8451 - mae: 6.3279
# Epoch 194/400
# 8/8 [==============================] - 0s 29ms/step - loss: 7.4383 - mae: 7.9262
# Epoch 195/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.5640 - mae: 7.0518
# Epoch 196/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.6894 - mae: 5.1662
# Epoch 197/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.5895 - mae: 5.0681
# Epoch 198/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1216 - mae: 4.5959
# Epoch 199/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4843 - mae: 4.9625
# Epoch 200/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5130 - mae: 4.9904
# Epoch 201/400
# 8/8 [==============================] - 0s 33ms/step - loss: 4.1161 - mae: 4.5961
# Epoch 202/400
# 8/8 [==============================] - 0s 26ms/step - loss: 5.0979 - mae: 5.5780
# Epoch 203/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4826 - mae: 4.9539
# Epoch 204/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.2890 - mae: 4.7675
# Epoch 205/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1551 - mae: 4.6260
# Epoch 206/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.5874 - mae: 5.0664
# Epoch 207/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.6870 - mae: 6.1699
# Epoch 208/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.4326 - mae: 8.9255
# Epoch 209/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.6535 - mae: 8.1390
# Epoch 210/400
# 8/8 [==============================] - 0s 26ms/step - loss: 7.3622 - mae: 7.8476
# Epoch 211/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.6974 - mae: 6.1800
# Epoch 212/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.4474 - mae: 4.9163
# Epoch 213/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9497 - mae: 5.4272
# Epoch 214/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6791 - mae: 5.1497
# Epoch 215/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.3770 - mae: 5.8597
# Epoch 216/400
# 8/8 [==============================] - 0s 31ms/step - loss: 6.0282 - mae: 6.5095
# Epoch 217/400
# 8/8 [==============================] - 0s 27ms/step - loss: 7.5029 - mae: 7.9910
# Epoch 218/400
# 8/8 [==============================] - 0s 27ms/step - loss: 7.9902 - mae: 8.4785
# Epoch 219/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.1889 - mae: 6.6737
# Epoch 220/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9717 - mae: 5.4542
# Epoch 221/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.2059 - mae: 5.6772
# Epoch 222/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.8064 - mae: 5.2853
# Epoch 223/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.8610 - mae: 5.3360
# Epoch 224/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.4550 - mae: 4.9317
# Epoch 225/400
# 8/8 [==============================] - 0s 32ms/step - loss: 5.1870 - mae: 5.6675
# Epoch 226/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.7505 - mae: 5.2287
# Epoch 227/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1184 - mae: 5.5954
# Epoch 228/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.3969 - mae: 4.8729
# Epoch 229/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1895 - mae: 4.6642
# Epoch 230/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.3719 - mae: 4.8479
# Epoch 231/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.1844 - mae: 5.6624
# Epoch 232/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.8939 - mae: 5.3689
# Epoch 233/400
# 8/8 [==============================] - 0s 33ms/step - loss: 4.9182 - mae: 5.3983
# Epoch 234/400
# 8/8 [==============================] - 0s 32ms/step - loss: 5.8794 - mae: 6.3618
# Epoch 235/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.3493 - mae: 5.8294
# Epoch 236/400
# 8/8 [==============================] - 0s 32ms/step - loss: 5.2983 - mae: 5.7778
# Epoch 237/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.1193 - mae: 5.6041
# Epoch 238/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.4807 - mae: 4.9621
# Epoch 239/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9371 - mae: 5.4192
# Epoch 240/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4579 - mae: 4.9365
# Epoch 241/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.4072 - mae: 4.8839
# Epoch 242/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.4956 - mae: 4.9726
# Epoch 243/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.6701 - mae: 6.1523
# Epoch 244/400
# 8/8 [==============================] - 0s 30ms/step - loss: 7.9080 - mae: 8.3932
# Epoch 245/400
# 8/8 [==============================] - 0s 28ms/step - loss: 7.1191 - mae: 7.6089
# Epoch 246/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.7778 - mae: 5.2566
# Epoch 247/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.1994 - mae: 4.6731
# Epoch 248/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.3967 - mae: 5.8796
# Epoch 249/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.7813 - mae: 6.2681
# Epoch 250/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.7352 - mae: 6.2164
# Epoch 251/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9032 - mae: 5.3826
# Epoch 252/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4333 - mae: 4.9143
# Epoch 253/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.2568 - mae: 5.7331
# Epoch 254/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.1574 - mae: 4.6306
# Epoch 255/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.1354 - mae: 4.6060
# Epoch 256/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.2631 - mae: 4.7337
# Epoch 257/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.3573 - mae: 4.8347
# Epoch 258/400
# 8/8 [==============================] - 0s 25ms/step - loss: 4.2638 - mae: 4.7405
# Epoch 259/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.0104 - mae: 4.4841
# Epoch 260/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.2403 - mae: 4.7179
# Epoch 261/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6607 - mae: 5.1333
# Epoch 262/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.3770 - mae: 4.8513
# Epoch 263/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.2634 - mae: 4.7406
# Epoch 264/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.7254 - mae: 5.1997
# Epoch 265/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.6056 - mae: 6.0891
# Epoch 266/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.3644 - mae: 4.8367
# Epoch 267/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.4612 - mae: 4.9417
# Epoch 268/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.2686 - mae: 4.7442
# Epoch 269/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.3095 - mae: 4.7865
# Epoch 270/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.2662 - mae: 4.7381
# Epoch 271/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.5142 - mae: 4.9913
# Epoch 272/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.2411 - mae: 4.7174
# Epoch 273/400
# 8/8 [==============================] - 0s 27ms/step - loss: 4.0770 - mae: 4.5547
# Epoch 274/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6153 - mae: 5.0932
# Epoch 275/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.5682 - mae: 5.0462
# Epoch 276/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.4342 - mae: 5.9150
# Epoch 277/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4842 - mae: 4.9621
# Epoch 278/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.1740 - mae: 4.6379
# Epoch 279/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.1925 - mae: 4.6633
# Epoch 280/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.2475 - mae: 4.7190
# Epoch 281/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6135 - mae: 5.0913
# Epoch 282/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.6139 - mae: 5.0903
# Epoch 283/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1770 - mae: 4.6483
# Epoch 284/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.1438 - mae: 4.6206
# Epoch 285/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.8754 - mae: 5.3554
# Epoch 286/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.2600 - mae: 5.7413
# Epoch 287/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.8784 - mae: 5.3560
# Epoch 288/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.8120 - mae: 5.2894
# Epoch 289/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.0082 - mae: 4.4788
# Epoch 290/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.2981 - mae: 4.7758
# Epoch 291/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.7125 - mae: 5.1924
# Epoch 292/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.0553 - mae: 5.5340
# Epoch 293/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.0112 - mae: 5.4881
# Epoch 294/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.9916 - mae: 5.4683
# Epoch 295/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1508 - mae: 5.6291
# Epoch 296/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.9008 - mae: 5.3827
# Epoch 297/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.4802 - mae: 5.9635
# Epoch 298/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6058 - mae: 5.0781
# Epoch 299/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.4040 - mae: 5.8862
# Epoch 300/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.1850 - mae: 5.6635
# Epoch 301/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.7413 - mae: 6.2231
# Epoch 302/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.8802 - mae: 6.3653
# Epoch 303/400
# 8/8 [==============================] - 0s 31ms/step - loss: 6.2033 - mae: 6.6920
# Epoch 304/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6025 - mae: 5.0759
# Epoch 305/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4809 - mae: 4.9598
# Epoch 306/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4841 - mae: 4.9614
# Epoch 307/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.8130 - mae: 5.2901
# Epoch 308/400
# 8/8 [==============================] - 0s 32ms/step - loss: 5.0551 - mae: 5.5345
# Epoch 309/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.0941 - mae: 5.5748
# Epoch 310/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.6671 - mae: 5.1457
# Epoch 311/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1567 - mae: 4.6327
# Epoch 312/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.6606 - mae: 5.1308
# Epoch 313/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.4233 - mae: 4.8965
# Epoch 314/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6075 - mae: 5.0870
# Epoch 315/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.2868 - mae: 4.7638
# Epoch 316/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.1105 - mae: 4.5854
# Epoch 317/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.2659 - mae: 4.7434
# Epoch 318/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.0120 - mae: 4.4898
# Epoch 319/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.9749 - mae: 5.4484
# Epoch 320/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4665 - mae: 4.9474
# Epoch 321/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.0811 - mae: 4.5555
# Epoch 322/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.1317 - mae: 4.6052
# Epoch 323/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.0707 - mae: 5.5496
# Epoch 324/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.3549 - mae: 4.8275
# Epoch 325/400
# 8/8 [==============================] - 0s 33ms/step - loss: 4.2403 - mae: 4.7158
# Epoch 326/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.0526 - mae: 5.5360
# Epoch 327/400
# 8/8 [==============================] - 0s 29ms/step - loss: 8.0891 - mae: 8.5804
# Epoch 328/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1068 - mae: 5.5837
# Epoch 329/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.5557 - mae: 5.0357
# Epoch 330/400
# 8/8 [==============================] - 0s 33ms/step - loss: 4.5454 - mae: 5.0221
# Epoch 331/400
# 8/8 [==============================] - 0s 33ms/step - loss: 4.6087 - mae: 5.0907
# Epoch 332/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.8006 - mae: 5.2815
# Epoch 333/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.7303 - mae: 6.2102
# Epoch 334/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.3690 - mae: 6.8531
# Epoch 335/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.3368 - mae: 6.8239
# Epoch 336/400
# 8/8 [==============================] - 0s 33ms/step - loss: 8.0343 - mae: 8.5251
# Epoch 337/400
# 8/8 [==============================] - 0s 31ms/step - loss: 6.3922 - mae: 6.8759
# Epoch 338/400
# 8/8 [==============================] - 0s 28ms/step - loss: 6.1079 - mae: 6.5911
# Epoch 339/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.5383 - mae: 7.0288
# Epoch 340/400
# 8/8 [==============================] - 0s 26ms/step - loss: 5.7248 - mae: 6.2093
# Epoch 341/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.4010 - mae: 6.8853
# Epoch 342/400
# 8/8 [==============================] - 0s 32ms/step - loss: 6.0478 - mae: 6.5342
# Epoch 343/400
# 8/8 [==============================] - 0s 30ms/step - loss: 6.7901 - mae: 7.2796
# Epoch 344/400
# 8/8 [==============================] - 0s 29ms/step - loss: 6.3277 - mae: 6.8139
# Epoch 345/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1966 - mae: 5.6751
# Epoch 346/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.3988 - mae: 4.8662
# Epoch 347/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.1001 - mae: 5.5843
# Epoch 348/400
# 8/8 [==============================] - 0s 28ms/step - loss: 5.5057 - mae: 5.9851
# Epoch 349/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.7225 - mae: 5.1966
# Epoch 350/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6375 - mae: 5.1166
# Epoch 351/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.5525 - mae: 6.0305
# Epoch 352/400
# 8/8 [==============================] - 0s 27ms/step - loss: 6.1811 - mae: 6.6661
# Epoch 353/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.4681 - mae: 5.9490
# Epoch 354/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.8442 - mae: 5.3221
# Epoch 355/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.4797 - mae: 4.9607
# Epoch 356/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.2821 - mae: 4.7570
# Epoch 357/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6866 - mae: 5.1637
# Epoch 358/400
# 8/8 [==============================] - 0s 33ms/step - loss: 5.6483 - mae: 6.1330
# Epoch 359/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.8992 - mae: 5.3748
# Epoch 360/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.3701 - mae: 4.8456
# Epoch 361/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5822 - mae: 5.0587
# Epoch 362/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.1408 - mae: 4.6194
# Epoch 363/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.5702 - mae: 5.0457
# Epoch 364/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.8641 - mae: 5.3424
# Epoch 365/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.4047 - mae: 4.8742
# Epoch 366/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.0309 - mae: 4.5092
# Epoch 367/400
# 8/8 [==============================] - 0s 27ms/step - loss: 5.2463 - mae: 5.7272
# Epoch 368/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.6237 - mae: 5.0976
# Epoch 369/400
# 8/8 [==============================] - 0s 26ms/step - loss: 4.6482 - mae: 5.1246
# Epoch 370/400
# 8/8 [==============================] - 0s 33ms/step - loss: 3.9807 - mae: 4.4548
# Epoch 371/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.0745 - mae: 4.5458
# Epoch 372/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.0317 - mae: 4.5041
# Epoch 373/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.2297 - mae: 4.7038
# Epoch 374/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.4133 - mae: 4.8921
# Epoch 375/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.8228 - mae: 5.3032
# Epoch 376/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.7925 - mae: 6.2753
# Epoch 377/400
# 8/8 [==============================] - 0s 30ms/step - loss: 5.6544 - mae: 6.1361
# Epoch 378/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.8637 - mae: 5.3437
# Epoch 379/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.2055 - mae: 4.6798
# Epoch 380/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.3721 - mae: 5.8554
# Epoch 381/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.4598 - mae: 4.9310
# Epoch 382/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.5202 - mae: 4.9961
# Epoch 383/400
# 8/8 [==============================] - 0s 31ms/step - loss: 4.0110 - mae: 4.4837
# Epoch 384/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.5370 - mae: 5.0108
# Epoch 385/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.6409 - mae: 5.1223
# Epoch 386/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.4799 - mae: 4.9554
# Epoch 387/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1680 - mae: 4.6416
# Epoch 388/400
# 8/8 [==============================] - 0s 32ms/step - loss: 4.3728 - mae: 4.8484
# Epoch 389/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.3858 - mae: 4.8610
# Epoch 390/400
# 8/8 [==============================] - 0s 30ms/step - loss: 3.8993 - mae: 4.3768
# Epoch 391/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.8064 - mae: 5.2856
# Epoch 392/400
# 8/8 [==============================] - 0s 29ms/step - loss: 5.7547 - mae: 6.2415
# Epoch 393/400
# 8/8 [==============================] - 0s 31ms/step - loss: 5.5750 - mae: 6.0590
# Epoch 394/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.6412 - mae: 5.1155
# Epoch 395/400
# 8/8 [==============================] - 0s 29ms/step - loss: 3.9184 - mae: 4.3948
# Epoch 396/400
# 8/8 [==============================] - 0s 29ms/step - loss: 4.1669 - mae: 4.6397
# Epoch 397/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.3599 - mae: 4.8372
# Epoch 398/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.1230 - mae: 4.5965
# Epoch 399/400
# 8/8 [==============================] - 0s 30ms/step - loss: 4.7049 - mae: 5.1776
# Epoch 400/400
# 8/8 [==============================] - 0s 28ms/step - loss: 4.6318 - mae: 5.1080

# %% [markdown]
# Vamos ahora a realizar predicciones y directamente dibujamos el valor real (azul)  y el obtenido por nuestro modelo (naranja)

# %%
forecast=[]
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %% [markdown]
# Obtenemos valor numérico de error para tener datos objetivos y comparables.

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 6.6208215

# %% [markdown]
# Vamos a plotear el error y la métrica de salida MAE para ver su relación. Los valores los tenemos en la lista `history[ ]`

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Recuperamos las listas de resultados de pérdida y error en el entrenamiento
#-----------------------------------------------------------
mae=history.history['mae']
loss=history.history['loss']

epochs=range(len(loss)) # Get number of epochs

#------------------------------------------------
# Ploteamos
#------------------------------------------------
plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

epochs_zoom = epochs[200:]
mae_zoom = mae[200:]
loss_zoom = loss[200:]

#------------------------------------------------
# Ploteamos con Zoom el MAE and Loss
#------------------------------------------------
plt.plot(epochs_zoom, mae_zoom, 'r')
plt.plot(epochs_zoom, loss_zoom, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

# %% [markdown]
# # Modelo con MLP (*MultiLayer Perceptron*)

# %% [markdown]
# Vamos a definir ahora una red neuronal multicapa de "similares" caracteristicas, al menos en cuanto a nº de neuronas y capas

# %%
model2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(40, input_shape=[window_size], activation="relu"), 
    tf.keras.layers.Dense(40, activation="relu"), 
    tf.keras.layers.Dense(1)
])

model2.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9))
history2 = model2.fit(dataset,epochs=400,verbose=0)

# %%
print(model2.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 40)                840
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 2,521
# Trainable params: 2,521
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
forecast = []
for time in range(len(series) - window_size):
  forecast.append(model2.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 4.7636824

# %% [markdown]
# Observa los resultados e intenta comprender lo que ocurre y porque. :
# * ¿Que arquitectura ha dado mejor resultado?
# * ¿Cual tiene más parámetros a entrenar?
# * ¿Porqué crees que ocurre?
# * ¿Como crees que se puede mejorar?
#
# Puedes consultar información al respecto aquí:
# https://datascience.stackexchange.com/questions/23029/why-are-rnn-lstm-preferred-in-time-series-analysis-and-not-other-nn

# %% [markdown]
# ##Referencias

# %% [markdown]
# *   Documento inspirado en los ejemplos del repositorio de LaurenceMorone y en su curso de Deep Learning con TensorFlow: https://github.com/lmoroney?tab=repositories
# * Doc oficial Pytorch https://pytorch.org/docs/stable/generated/torch.nn.RNN.html
# * https://pytorch.org/tutorials/intermediate/char_rnn_classification_tutorial.html

# %% [markdown]
# ## Fin del cuaderno
