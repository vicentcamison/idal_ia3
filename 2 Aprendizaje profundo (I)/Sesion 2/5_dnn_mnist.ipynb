# %% [markdown]
# <a href="https://colab.research.google.com/github/vicentcamison/idal_ia3/blob/main/2%20Aprendizaje%20profundo%20(I)/Sesion%202/5_dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (754)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model = tf.keras.models.Sequential()
model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))


# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 1s 5ms/step - loss: 0.5058 - accuracy: 0.8525 - val_loss: 0.2058 - val_accuracy: 0.9420
# Epoch 2/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9536 - val_loss: 0.1443 - val_accuracy: 0.9588
# Epoch 3/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1103 - accuracy: 0.9674 - val_loss: 0.1058 - val_accuracy: 0.9680
# Epoch 4/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9754 - val_loss: 0.0874 - val_accuracy: 0.9725
# Epoch 5/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0628 - accuracy: 0.9814 - val_loss: 0.0868 - val_accuracy: 0.9725
# Epoch 6/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9845 - val_loss: 0.0795 - val_accuracy: 0.9770
# Epoch 7/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9879 - val_loss: 0.0726 - val_accuracy: 0.9786
# Epoch 8/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9896 - val_loss: 0.0773 - val_accuracy: 0.9772
# Epoch 9/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.0797 - val_accuracy: 0.9777
# Epoch 10/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0727 - val_accuracy: 0.9795
# Epoch 11/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.0782 - val_accuracy: 0.9782
# Epoch 12/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.0866 - val_accuracy: 0.9756
# Epoch 13/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.1017 - val_accuracy: 0.9742
# Epoch 14/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 0.0768 - val_accuracy: 0.9803
# Epoch 15/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0881 - val_accuracy: 0.9778
# Epoch 16/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.0814 - val_accuracy: 0.9798
# Epoch 17/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0878 - val_accuracy: 0.9782
# Epoch 18/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.1018 - val_accuracy: 0.9759
# Epoch 19/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.1089 - val_accuracy: 0.9773
# Epoch 20/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0983 - val_accuracy: 0.9778
# Epoch 21/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.0974 - val_accuracy: 0.9787
# Epoch 22/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1001 - val_accuracy: 0.9795
# Epoch 23/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0997 - val_accuracy: 0.9792
# Epoch 24/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.1121 - val_accuracy: 0.9786
# Epoch 25/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.1213 - val_accuracy: 0.9746
# Epoch 26/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.1072 - val_accuracy: 0.9794
# Epoch 27/35
# 118/118 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1109 - val_accuracy: 0.9796
# Epoch 28/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1043 - val_accuracy: 0.9791
# Epoch 29/35
# 118/118 [==============================] - 0s 4ms/step - loss: 5.5485e-04 - accuracy: 0.9999 - val_loss: 0.0969 - val_accuracy: 0.9825
# Epoch 30/35
# 118/118 [==============================] - 0s 4ms/step - loss: 1.9138e-04 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9825
# Epoch 31/35
# 118/118 [==============================] - 0s 4ms/step - loss: 1.3592e-04 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9823
# Epoch 32/35
# 118/118 [==============================] - 0s 4ms/step - loss: 1.1551e-04 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9823
# Epoch 33/35
# 118/118 [==============================] - 0s 4ms/step - loss: 8.7495e-05 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9827
# Epoch 34/35
# 118/118 [==============================] - 0s 4ms/step - loss: 7.8972e-05 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9828
# Epoch 35/35
# 118/118 [==============================] - 0s 4ms/step - loss: 6.9853e-05 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9827

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

#hay OVERFITTING tal y como se puede apreciar en las gráficas

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')] #esto se llama COMPRESSION LIST
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50
reg = 0.01

# Crear modelo
model_with_l2 = tf.keras.models.Sequential()
model_with_l2.add(Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg), input_shape=(X_train.shape[1],)))
model_with_l2.add(Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 1s 5ms/step - loss: 1.6548 - accuracy: 0.8467 - val_loss: 0.8745 - val_accuracy: 0.9080
# Epoch 2/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.8175 - accuracy: 0.9140 - val_loss: 0.7635 - val_accuracy: 0.9161
# Epoch 3/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.7301 - accuracy: 0.9242 - val_loss: 0.7135 - val_accuracy: 0.9231
# Epoch 4/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6802 - accuracy: 0.9302 - val_loss: 0.6786 - val_accuracy: 0.9266
# Epoch 5/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.9332 - val_loss: 0.6207 - val_accuracy: 0.9366
# Epoch 6/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.9382 - val_loss: 0.6424 - val_accuracy: 0.9217
# Epoch 7/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6046 - accuracy: 0.9376 - val_loss: 0.5807 - val_accuracy: 0.9419
# Epoch 8/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5819 - accuracy: 0.9420 - val_loss: 0.5997 - val_accuracy: 0.9352
# Epoch 9/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5738 - accuracy: 0.9429 - val_loss: 0.5618 - val_accuracy: 0.9400
# Epoch 10/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.5597 - accuracy: 0.9446 - val_loss: 0.5534 - val_accuracy: 0.9433
# Epoch 11/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5478 - accuracy: 0.9467 - val_loss: 0.5541 - val_accuracy: 0.9403
# Epoch 12/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5400 - accuracy: 0.9474 - val_loss: 0.5295 - val_accuracy: 0.9490
# Epoch 13/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5314 - accuracy: 0.9477 - val_loss: 0.5192 - val_accuracy: 0.9477
# Epoch 14/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5204 - accuracy: 0.9493 - val_loss: 0.5229 - val_accuracy: 0.9481
# Epoch 15/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5128 - accuracy: 0.9500 - val_loss: 0.4980 - val_accuracy: 0.9540
# Epoch 16/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5030 - accuracy: 0.9525 - val_loss: 0.5047 - val_accuracy: 0.9500
# Epoch 17/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5002 - accuracy: 0.9519 - val_loss: 0.4868 - val_accuracy: 0.9529
# Epoch 18/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4926 - accuracy: 0.9522 - val_loss: 0.4854 - val_accuracy: 0.9531
# Epoch 19/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4870 - accuracy: 0.9544 - val_loss: 0.4778 - val_accuracy: 0.9557
# Epoch 20/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4816 - accuracy: 0.9542 - val_loss: 0.4731 - val_accuracy: 0.9540
# Epoch 21/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.9545 - val_loss: 0.4742 - val_accuracy: 0.9525
# Epoch 22/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4706 - accuracy: 0.9555 - val_loss: 0.4630 - val_accuracy: 0.9564
# Epoch 23/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4673 - accuracy: 0.9556 - val_loss: 0.4544 - val_accuracy: 0.9573
# Epoch 24/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4609 - accuracy: 0.9561 - val_loss: 0.4499 - val_accuracy: 0.9560
# Epoch 25/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.9573 - val_loss: 0.4578 - val_accuracy: 0.9557
# Epoch 26/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.4539 - accuracy: 0.9571 - val_loss: 0.4600 - val_accuracy: 0.9516
# Epoch 27/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.4514 - accuracy: 0.9572 - val_loss: 0.4420 - val_accuracy: 0.9589
# Epoch 28/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4469 - accuracy: 0.9576 - val_loss: 0.4463 - val_accuracy: 0.9574
# Epoch 29/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4428 - accuracy: 0.9585 - val_loss: 0.4617 - val_accuracy: 0.9482
# Epoch 30/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4414 - accuracy: 0.9580 - val_loss: 0.4434 - val_accuracy: 0.9559
# Epoch 31/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4388 - accuracy: 0.9582 - val_loss: 0.4341 - val_accuracy: 0.9570
# Epoch 32/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.9588 - val_loss: 0.4372 - val_accuracy: 0.9531
# Epoch 33/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.9600 - val_loss: 0.4270 - val_accuracy: 0.9579
# Epoch 34/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4259 - accuracy: 0.9599 - val_loss: 0.4231 - val_accuracy: 0.9592
# Epoch 35/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4261 - accuracy: 0.9592 - val_loss: 0.4351 - val_accuracy: 0.9547
# Epoch 36/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.9592 - val_loss: 0.4226 - val_accuracy: 0.9592
# Epoch 37/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4196 - accuracy: 0.9613 - val_loss: 0.4199 - val_accuracy: 0.9580
# Epoch 38/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4173 - accuracy: 0.9607 - val_loss: 0.4146 - val_accuracy: 0.9604
# Epoch 39/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4176 - accuracy: 0.9601 - val_loss: 0.4106 - val_accuracy: 0.9601
# Epoch 40/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4127 - accuracy: 0.9608 - val_loss: 0.4039 - val_accuracy: 0.9616
# Epoch 41/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.9618 - val_loss: 0.3982 - val_accuracy: 0.9634
# Epoch 42/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.9614 - val_loss: 0.4167 - val_accuracy: 0.9581
# Epoch 43/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4035 - accuracy: 0.9629 - val_loss: 0.4031 - val_accuracy: 0.9598
# Epoch 44/50
# 118/118 [==============================] - 1s 4ms/step - loss: 0.4030 - accuracy: 0.9615 - val_loss: 0.4217 - val_accuracy: 0.9528
# Epoch 45/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4010 - accuracy: 0.9611 - val_loss: 0.3963 - val_accuracy: 0.9619
# Epoch 46/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.9625 - val_loss: 0.4077 - val_accuracy: 0.9590
# Epoch 47/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3987 - accuracy: 0.9615 - val_loss: 0.3975 - val_accuracy: 0.9605
# Epoch 48/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3931 - accuracy: 0.9629 - val_loss: 0.3957 - val_accuracy: 0.9605
# Epoch 49/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3898 - accuracy: 0.9636 - val_loss: 0.4046 - val_accuracy: 0.9550
# Epoch 50/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.9632 - val_loss: 0.3915 - val_accuracy: 0.9599

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
rt = 0.4

model_with_dp = tf.keras.models.Sequential()
model_with_dp.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model_with_dp.add(Dropout(rt))
model_with_dp.add(Dense(128, activation='relu'))
model_with_dp.add(Dropout(rt))
model_with_dp.add(Dense(64, activation='relu'))
model_with_dp.add(Dropout(rt))
model_with_dp.add(Dense(32, activation='relu'))
model_with_dp.add(Dropout(rt))
model_with_dp.add(Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 1s 5ms/step - loss: 0.9235 - accuracy: 0.6948 - val_loss: 0.2355 - val_accuracy: 0.9382
# Epoch 2/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3967 - accuracy: 0.9002 - val_loss: 0.1716 - val_accuracy: 0.9547
# Epoch 3/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3088 - accuracy: 0.9243 - val_loss: 0.1560 - val_accuracy: 0.9584
# Epoch 4/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.9348 - val_loss: 0.1390 - val_accuracy: 0.9644
# Epoch 5/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.2390 - accuracy: 0.9420 - val_loss: 0.1353 - val_accuracy: 0.9675
# Epoch 6/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.9456 - val_loss: 0.1250 - val_accuracy: 0.9721
# Epoch 7/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.2063 - accuracy: 0.9506 - val_loss: 0.1226 - val_accuracy: 0.9714
# Epoch 8/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.9529 - val_loss: 0.1115 - val_accuracy: 0.9729
# Epoch 9/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9561 - val_loss: 0.1132 - val_accuracy: 0.9734
# Epoch 10/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9569 - val_loss: 0.1146 - val_accuracy: 0.9727
# Epoch 11/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1606 - accuracy: 0.9610 - val_loss: 0.1098 - val_accuracy: 0.9746
# Epoch 12/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1607 - accuracy: 0.9618 - val_loss: 0.1118 - val_accuracy: 0.9744
# Epoch 13/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1556 - accuracy: 0.9627 - val_loss: 0.1128 - val_accuracy: 0.9745
# Epoch 14/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1472 - accuracy: 0.9649 - val_loss: 0.1047 - val_accuracy: 0.9764
# Epoch 15/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1454 - accuracy: 0.9655 - val_loss: 0.1058 - val_accuracy: 0.9765
# Epoch 16/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.9661 - val_loss: 0.1077 - val_accuracy: 0.9761
# Epoch 17/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1355 - accuracy: 0.9676 - val_loss: 0.1060 - val_accuracy: 0.9758
# Epoch 18/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9665 - val_loss: 0.1093 - val_accuracy: 0.9768
# Epoch 19/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9685 - val_loss: 0.1015 - val_accuracy: 0.9782
# Epoch 20/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.9682 - val_loss: 0.1069 - val_accuracy: 0.9762
# Epoch 21/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1280 - accuracy: 0.9688 - val_loss: 0.1045 - val_accuracy: 0.9776
# Epoch 22/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1207 - accuracy: 0.9700 - val_loss: 0.1087 - val_accuracy: 0.9773
# Epoch 23/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1183 - accuracy: 0.9720 - val_loss: 0.1029 - val_accuracy: 0.9775
# Epoch 24/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1155 - accuracy: 0.9722 - val_loss: 0.1024 - val_accuracy: 0.9782
# Epoch 25/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9725 - val_loss: 0.1075 - val_accuracy: 0.9779

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
